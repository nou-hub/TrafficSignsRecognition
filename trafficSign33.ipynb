# %% [markdown]
# <a href="https://colab.research.google.com/github/nou-hub/TrafficSignsRecognition/blob/main/trafficSign33.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
import shutil
import random

# !pip install tqdm --upgrade
from tqdm.notebook import tqdm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !touch data.yaml

# %%
import ultralytics

# %%
# !yolo task=detect mode=train model="yolov8s.pt" data="/content/data.yaml"  epochs=10 imgsz=640 batch=8 project="/content/drive/MyDrive" name="traffic"
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 197MB/s]
# Ultralytics YOLOv8.2.66 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/traffic/weights/best.pt" conf=0.55 source="/content/drive/MyDrive/TrafficSign dataset 3/test/images"
# Out:
# Ultralytics YOLOv8.2.66 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,129,067 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/212 /content/drive/MyDrive/TrafficSign dataset 3/test/images/0_10001_1577671998-65016_png.rf.59529f16da80c77f1f2a988cfd19d21f.jpg: 640x640 1 SPEED LIMIT 20, 16.4ms
# image 2/212 /content/drive/MyDrive/TrafficSign dataset 3/test/images/0_10003_1577671998-651159_png.rf.925cb00ad4b239aaa3259698d86731b0.jpg: 640x640 1 SPEED LIMIT 20, 16.4ms
# image 3/212 /content/drive/MyDrive/TrafficSign dataset 3/test/images/0_10008_1577671998-6551478_png.rf.7d64bc935cccf8a2ae82e56c492ee34c.jpg: 640x640 1 SPEED LIMIT 20, 17.2ms
# image 4/212 /content/drive/MyDrive/TrafficSign dataset 3/test/images/0_10020_1577671998-6641226_png.rf.630be831470608811f8e8d89573a10b2.jpg: 640x640 1 SPEED LIMIT 20, 16.4ms
# ...

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/traffic/weights/best.pt" conf=0.71 source="/content/drive/MyDrive/TrafficSign dataset 3/vids"
# Out:
# Ultralytics YOLOv8.2.64 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,129,067 parameters, 0 gradients, 28.5 GFLOPs
#
# video 1/2 (frame 1/156) /content/drive/MyDrive/TrafficSign dataset 3/vids/vecteezy_traffic22.mp4: 384x640 1 STOP, 176.3ms
# video 1/2 (frame 2/156) /content/drive/MyDrive/TrafficSign dataset 3/vids/vecteezy_traffic22.mp4: 384x640 (no detections), 13.2ms
# video 1/2 (frame 3/156) /content/drive/MyDrive/TrafficSign dataset 3/vids/vecteezy_traffic22.mp4: 384x640 (no detections), 16.2ms
# video 1/2 (frame 4/156) /content/drive/MyDrive/TrafficSign dataset 3/vids/vecteezy_traffic22.mp4: 384x640 (no detections), 10.7ms
# video 1/2 (frame 5/156) /content/drive/MyDrive/TrafficSign dataset 3/vids/vecteezy_traffic22.mp4: 384x640 (no detections), 12.6ms
# video 1/2 (frame 6/156) /content/drive/MyDrive/TrafficSign dataset 3/vids/vecteezy_traffic22.mp4: 384x640 (no detections), 13.3ms
# ...

# %%
# !cp -r '/content/runs/detect/predict2'  '/content/drive/MyDrive/TrafficSign dataset 3/outputs'
